# %%
print("Abhishek Kumar Purbey")
# Out:
# Abhishek Kumar Purbey

# %%
print("Abhusbehenwm nsdfk")
# Out:
# Abhusbehenwm nsdfk

# %%
print("Day 1 ML preprocessing practice")
# Out:
# Day 1 ML preprocessing practice

# %%
import sys
print(sys.executable)
# Out:
# c:\ProgramData\anaconda3\python.exe

# %%
import numpy as np
import pandas as pd

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy: 2.3.5
# Pandas: 2.3.3
